# %% [markdown]
# ## Deliverable 1.  Retrieve Weather Data

# %%
# Import all necessary libraries and the openweathermap API key
import numpy as np
import pandas as pd
import requests
from citipy import citipy
from datetime import datetime
import time

from config import openweather_api_key

# %%
# Create the base url, including the API key and request for imperial (US) units
url = "http://api.openweathermap.org/data/2.5/weather?" + "appid=" + openweather_api_key + "&units=imperial"

# %%
# Create a set of random latitude and longitude combinations.
num_lat_longs = 2000
lats = np.random.uniform(low=-90.000, high=90.000, size=num_lat_longs)
lngs = np.random.uniform(low=-180.000, high=180.000, size=num_lat_longs)
coordinates = zip(lats, lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
print(f'Number of cities:  {len(cities)}')
# Out:
# Number of cities:  733

# %% [markdown]
# ## Download the weather data from openweatherapi.org; this will take several minutes due to limitations with the free subscription

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
# Capture the start time, this is used later to make sure we do not
# interrogate the API more than 60 times per second
start_time = time.time()
for i, city in enumerate(cities):
    
    # Group cities in sets of 60 for logging and API call management.
    if (i % 60 == 0 and i >= 60):
        set_count += 1
        record_count = 1
        
        # If this series of 60 calls took less than 60 seconds, then wait until
        # 61 seconds has elapsed (add 1 second margin)
        curr_time = time.time()
        elapsed_time = curr_time - start_time
        if elapsed_time < 61:
            wait_time = 61 - elapsed_time
            print (f"Waiting {wait_time:.0f} seconds for next API time slot...")
            time.sleep(wait_time)
            # Capture a new start time for the next block
            start_time = time.time()
            
    # Create endpoint URL for the current city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for the current city
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description" : city_weather_desc})

    except KeyError:
        # A KeyError exception is thrown at the line "city_lat = ..."  if the
        #  API does not return any city data.
        print(city + " not found. Skipping...")
        pass
    
    except BaseException as ex:
        # Some other exception occurred, print it to the log
        print(f'Unknown exception:  {ex}')    

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | upernavik
# Processing Record 2 of Set 1 | norman wells
# Processing Record 3 of Set 1 | sosnogorsk
# Processing Record 4 of Set 1 | cape town
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | barrow
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | saint-philippe
# Processing Record 10 of Set 1 | acapulco
# Processing Record 11 of Set 1 | avarua
# Processing Record 12 of Set 1 | ormara
# Processing Record 13 of Set 1 | kaeo
# Processing Record 14 of Set 1 | meadow lake
# Processing Record 15 of Set 1 | hasaki
# Processing Record 16 of Set 1 | qaqortoq
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | illoqqortoormiut
# illoqqortoormiut not found. Skipping...
# Processing Record 19 of Set 1 | kailua
# Processing Record 20 of Set 1 | marsa matruh
# Processing Record 21 of Set 1 | porto murtinho
# Processing Record 22 of Set 1 | itaituba
# Processing Record 23 of Set 1 | vaini
# Processing Record 24 of Set 1 | bethel
# Processing Record 25 of Set 1 | namibe
# Processing Record 26 of Set 1 | deputatskiy
# Processing Record 27 of Set 1 | adwa
# Processing Record 28 of Set 1 | attawapiskat
# attawapiskat not found. Skipping...
# Processing Record 29 of Set 1 | port elizabeth
# Processing Record 30 of Set 1 | nikolskoye
# Processing Record 31 of Set 1 | georgetown
# Processing Record 32 of Set 1 | provideniya
# Processing Record 33 of Set 1 | kahului
# Processing Record 34 of Set 1 | pevek
# Processing Record 35 of Set 1 | ridgecrest
# Processing Record 36 of Set 1 | punta arenas
# Processing Record 37 of Set 1 | gelemso
# Processing Record 38 of Set 1 | mucuri
# Processing Record 39 of Set 1 | taolanaro
# taolanaro not found. Skipping...
# Processing Record 40 of Set 1 | abu samrah
# Processing Record 41 of Set 1 | iquique
# Processing Record 42 of Set 1 | touros
# Processing Record 43 of Set 1 | barentsburg
# barentsburg not found. Skipping...
# Processing Record 44 of Set 1 | jamestown
# Processing Record 45 of Set 1 | bambous virieux
# Processing Record 46 of Set 1 | san patricio
# Processing Record 47 of Set 1 | hilo
# Processing Record 48 of Set 1 | atuona
# Processing Record 49 of Set 1 | anadyr
# Processing Record 50 of Set 1 | kurilsk
# Processing Record 51 of Set 1 | albany
# Processing Record 52 of Set 1 | carnarvon
# Processing Record 53 of Set 1 | lavrentiya
# Processing Record 54 of Set 1 | port alfred
# Processing Record 55 of Set 1 | ostrovnoy
# Processing Record 56 of Set 1 | paciran
# Processing Record 57 of Set 1 | ancud
# Processing Record 58 of Set 1 | puerto ayora
# Processing Record 59 of Set 1 | souillac
# Processing Record 60 of Set 1 | nioro
# Waiting 45 seconds for next API time slot...
# Processing Record 1 of Set 2 | luderitz
# Processing Record 2 of Set 2 | talnakh
# Processing Record 3 of Set 2 | ponta do sol
# Processing Record 4 of Set 2 | kruisfontein
# Processing Record 5 of Set 2 | hambantota
# Processing Record 6 of Set 2 | sisimiut
# Processing Record 7 of Set 2 | hermanus
# Processing Record 8 of Set 2 | sept-iles
# Processing Record 9 of Set 2 | baghdad
# Processing Record 10 of Set 2 | hobart
# Processing Record 11 of Set 2 | mayo
# Processing Record 12 of Set 2 | klaksvik
# Processing Record 13 of Set 2 | djibo
# Processing Record 14 of Set 2 | severo-kurilsk
# Processing Record 15 of Set 2 | kudahuvadhoo
# Processing Record 16 of Set 2 | butaritari
# Processing Record 17 of Set 2 | sao joao da barra
# Processing Record 18 of Set 2 | esperance
# Processing Record 19 of Set 2 | joshimath
# Processing Record 20 of Set 2 | new norfolk
# Processing Record 21 of Set 2 | thompson
# Processing Record 22 of Set 2 | cherskiy
# Processing Record 23 of Set 2 | gotsu
# Processing Record 24 of Set 2 | borzya
# Processing Record 25 of Set 2 | kaitangata
# Processing Record 26 of Set 2 | fortuna
# Processing Record 27 of Set 2 | phan thiet
# Processing Record 28 of Set 2 | comodoro rivadavia
# Processing Record 29 of Set 2 | cam ranh
# Processing Record 30 of Set 2 | kodiak
# Processing Record 31 of Set 2 | marica
# Processing Record 32 of Set 2 | nuevo ideal
# Processing Record 33 of Set 2 | port hedland
# Processing Record 34 of Set 2 | nemuro
# Processing Record 35 of Set 2 | vila franca do campo
# Processing Record 36 of Set 2 | sentyabrskiy
# sentyabrskiy not found. Skipping...
# Processing Record 37 of Set 2 | mengcheng
# Processing Record 38 of Set 2 | troitskoye
# Processing Record 39 of Set 2 | bredasdorp
# Processing Record 40 of Set 2 | liure
# Processing Record 41 of Set 2 | cabatuan
# Processing Record 42 of Set 2 | belushya guba
# belushya guba not found. Skipping...
# Processing Record 43 of Set 2 | kamina
# Processing Record 44 of Set 2 | peniche
# Processing Record 45 of Set 2 | arraial do cabo
# Processing Record 46 of Set 2 | port macquarie
# Processing Record 47 of Set 2 | usinsk
# Processing Record 48 of Set 2 | faanui
# Processing Record 49 of Set 2 | college
# Processing Record 50 of Set 2 | isangel
# Processing Record 51 of Set 2 | dicabisagan
# Processing Record 52 of Set 2 | guerrero negro
# Processing Record 53 of Set 2 | vao
# Processing Record 54 of Set 2 | victoria
# Processing Record 55 of Set 2 | namie
# Processing Record 56 of Set 2 | amderma
# amderma not found. Skipping...
# Processing Record 57 of Set 2 | east london
# Processing Record 58 of Set 2 | lompoc
# Processing Record 59 of Set 2 | straumen
# Processing Record 60 of Set 2 | adrar
# Waiting 43 seconds for next API time slot...
# Processing Record 1 of Set 3 | kapaa
# Processing Record 2 of Set 3 | saleaula
# saleaula not found. Skipping...
# Processing Record 3 of Set 3 | martinho campos
# Processing Record 4 of Set 3 | falkenberg
# Processing Record 5 of Set 3 | vostok
# Processing Record 6 of Set 3 | yellowknife
# Processing Record 7 of Set 3 | codrington
# Processing Record 8 of Set 3 | chapleau
# Processing Record 9 of Set 3 | kampong cham
# Processing Record 10 of Set 3 | laguna
# Processing Record 11 of Set 3 | rosarito
# Processing Record 12 of Set 3 | xuanhua
# Processing Record 13 of Set 3 | kavieng
# Processing Record 14 of Set 3 | mahebourg
# Processing Record 15 of Set 3 | hirara
# Processing Record 16 of Set 3 | dakoro
# Processing Record 17 of Set 3 | hithadhoo
# Processing Record 18 of Set 3 | bonavista
# Processing Record 19 of Set 3 | talah
# talah not found. Skipping...
# Processing Record 20 of Set 3 | mmathubudukwane
# Processing Record 21 of Set 3 | derzhavinsk
# Processing Record 22 of Set 3 | wittlich
# Processing Record 23 of Set 3 | portland
# Processing Record 24 of Set 3 | zaraza
# Processing Record 25 of Set 3 | mayumba
# Processing Record 26 of Set 3 | vila velha
# Processing Record 27 of Set 3 | rungata
# rungata not found. Skipping...
# Processing Record 28 of Set 3 | dikson
# Processing Record 29 of Set 3 | malinovoye ozero
# Processing Record 30 of Set 3 | nizhneyansk
# nizhneyansk not found. Skipping...
# Processing Record 31 of Set 3 | lata
# Processing Record 32 of Set 3 | pisco
# Processing Record 33 of Set 3 | zhicheng
# Processing Record 34 of Set 3 | tiksi
# Processing Record 35 of Set 3 | mumbwa
# Processing Record 36 of Set 3 | asayita
# asayita not found. Skipping...
# Processing Record 37 of Set 3 | paisley
# Processing Record 38 of Set 3 | socorro
# Processing Record 39 of Set 3 | qaanaaq
# Processing Record 40 of Set 3 | nishihara
# Processing Record 41 of Set 3 | linxia
# Processing Record 42 of Set 3 | saskylakh
# Processing Record 43 of Set 3 | vardo
# Processing Record 44 of Set 3 | teguldet
# Processing Record 45 of Set 3 | constitucion
# Processing Record 46 of Set 3 | saint-augustin
# Processing Record 47 of Set 3 | jati
# Processing Record 48 of Set 3 | grand gaube
# Processing Record 49 of Set 3 | la libertad
# Processing Record 50 of Set 3 | valdivia
# Processing Record 51 of Set 3 | ardahan
# Processing Record 52 of Set 3 | mount gambier
# Processing Record 53 of Set 3 | amapa
# Processing Record 54 of Set 3 | show low
# Processing Record 55 of Set 3 | longyearbyen
# Processing Record 56 of Set 3 | mrirt
# mrirt not found. Skipping...
# Processing Record 57 of Set 3 | tahoua
# Processing Record 58 of Set 3 | reitz
# Processing Record 59 of Set 3 | grand river south east
# grand river south east not found. Skipping...
# Processing Record 60 of Set 3 | mayor pablo lagerenza
# Waiting 45 seconds for next API time slot...
# Processing Record 1 of Set 4 | bilma
# Processing Record 2 of Set 4 | saint pete beach
# Processing Record 3 of Set 4 | angoche
# Processing Record 4 of Set 4 | lebu
# Processing Record 5 of Set 4 | nizhnyaya pavlovka
# nizhnyaya pavlovka not found. Skipping...
# Processing Record 6 of Set 4 | bluff
# Processing Record 7 of Set 4 | temaraia
# temaraia not found. Skipping...
# Processing Record 8 of Set 4 | yulara
# Processing Record 9 of Set 4 | yar-sale
# Processing Record 10 of Set 4 | nome
# Processing Record 11 of Set 4 | leningradskiy
# Processing Record 12 of Set 4 | saint-georges
# Processing Record 13 of Set 4 | shawville
# Processing Record 14 of Set 4 | xining
# Processing Record 15 of Set 4 | bandarbeyla
# Processing Record 16 of Set 4 | saldanha
# Processing Record 17 of Set 4 | aksarka
# Processing Record 18 of Set 4 | castro
# Processing Record 19 of Set 4 | batemans bay
# Processing Record 20 of Set 4 | clinton
# Processing Record 21 of Set 4 | provost
# Processing Record 22 of Set 4 | rodeo
# Processing Record 23 of Set 4 | viligili
# viligili not found. Skipping...
# Processing Record 24 of Set 4 | sibolga
# Processing Record 25 of Set 4 | bengkulu
# Processing Record 26 of Set 4 | portales
# Processing Record 27 of Set 4 | bontang
# Processing Record 28 of Set 4 | louisbourg
# louisbourg not found. Skipping...
# Processing Record 29 of Set 4 | matam
# Processing Record 30 of Set 4 | caravelas
# Processing Record 31 of Set 4 | rorvik
# Processing Record 32 of Set 4 | boyolangu
# Processing Record 33 of Set 4 | carutapera
# Processing Record 34 of Set 4 | tuktoyaktuk
# Processing Record 35 of Set 4 | bolungarvik
# bolungarvik not found. Skipping...
# Processing Record 36 of Set 4 | airai
# Processing Record 37 of Set 4 | neumunster
# Processing Record 38 of Set 4 | maldonado
# Processing Record 39 of Set 4 | bratsk
# Processing Record 40 of Set 4 | port hardy
# Processing Record 41 of Set 4 | tulun
# Processing Record 42 of Set 4 | alofi
# Processing Record 43 of Set 4 | vestmannaeyjar
# Processing Record 44 of Set 4 | zhezkazgan
# Processing Record 45 of Set 4 | benque viejo
# benque viejo not found. Skipping...
# Processing Record 46 of Set 4 | plouzane
# Processing Record 47 of Set 4 | traverse city
# Processing Record 48 of Set 4 | charlestown
# Processing Record 49 of Set 4 | kodinsk
# Processing Record 50 of Set 4 | hommelvik
# Processing Record 51 of Set 4 | tasiilaq
# Processing Record 52 of Set 4 | cidreira
# Processing Record 53 of Set 4 | puerto del rosario
# Processing Record 54 of Set 4 | ouro branco
# Processing Record 55 of Set 4 | maniitsoq
# Processing Record 56 of Set 4 | gunnedah
# Processing Record 57 of Set 4 | ambilobe
# Processing Record 58 of Set 4 | longonjo
# Processing Record 59 of Set 4 | thoen
# Processing Record 60 of Set 4 | bratca
# Waiting 43 seconds for next API time slot...
# Processing Record 1 of Set 5 | tiznit
# Processing Record 2 of Set 5 | beringovskiy
# Processing Record 3 of Set 5 | marienburg
# Processing Record 4 of Set 5 | mount isa
# Processing Record 5 of Set 5 | cabo san lucas
# Processing Record 6 of Set 5 | broken hill
# Processing Record 7 of Set 5 | hervey bay
# Processing Record 8 of Set 5 | chuy
# Processing Record 9 of Set 5 | mys shmidta
# mys shmidta not found. Skipping...
# Processing Record 10 of Set 5 | taoudenni
# Processing Record 11 of Set 5 | iqaluit
# Processing Record 12 of Set 5 | ostersund
# Processing Record 13 of Set 5 | nyurba
# Processing Record 14 of Set 5 | laurel
# Processing Record 15 of Set 5 | karamea
# karamea not found. Skipping...
# Processing Record 16 of Set 5 | luau
# Processing Record 17 of Set 5 | kieta
# Processing Record 18 of Set 5 | kamenka
# Processing Record 19 of Set 5 | plettenberg bay
# Processing Record 20 of Set 5 | ribeira grande
# Processing Record 21 of Set 5 | ilulissat
# Processing Record 22 of Set 5 | yugorsk
# Processing Record 23 of Set 5 | chicama
# Processing Record 24 of Set 5 | clarence town
# Processing Record 25 of Set 5 | arkhipo-osipovka
# Processing Record 26 of Set 5 | dingle
# Processing Record 27 of Set 5 | nkayi
# Processing Record 28 of Set 5 | nancha
# Processing Record 29 of Set 5 | meulaboh
# Processing Record 30 of Set 5 | capaci
# Processing Record 31 of Set 5 | olafsvik
# Processing Record 32 of Set 5 | coihaique
# Processing Record 33 of Set 5 | gisborne
# Processing Record 34 of Set 5 | toledo
# Processing Record 35 of Set 5 | magway
# Processing Record 36 of Set 5 | komsomolskiy
# Processing Record 37 of Set 5 | gizo
# Processing Record 38 of Set 5 | hollins
# Processing Record 39 of Set 5 | lagoa
# Processing Record 40 of Set 5 | kristianstad
# Processing Record 41 of Set 5 | mar del plata
# Processing Record 42 of Set 5 | prince rupert
# Processing Record 43 of Set 5 | wampusirpi
# wampusirpi not found. Skipping...
# Processing Record 44 of Set 5 | souris
# Processing Record 45 of Set 5 | kidal
# Processing Record 46 of Set 5 | intipuca
# Processing Record 47 of Set 5 | tuatapere
# Processing Record 48 of Set 5 | coquimbo
# Processing Record 49 of Set 5 | vredendal
# Processing Record 50 of Set 5 | south lake tahoe
# Processing Record 51 of Set 5 | orange
# Processing Record 52 of Set 5 | kysyl-syr
# Processing Record 53 of Set 5 | akdepe
# Processing Record 54 of Set 5 | daru
# Processing Record 55 of Set 5 | saran
# Processing Record 56 of Set 5 | angra
# angra not found. Skipping...
# Processing Record 57 of Set 5 | volchikha
# Processing Record 58 of Set 5 | banjarmasin
# Processing Record 59 of Set 5 | canitas
# canitas not found. Skipping...
# Processing Record 60 of Set 5 | ulaanbaatar
# Waiting 43 seconds for next API time slot...
# Processing Record 1 of Set 6 | pitimbu
# Processing Record 2 of Set 6 | novy bydzov
# Processing Record 3 of Set 6 | san cristobal
# Processing Record 4 of Set 6 | clyde river
# Processing Record 5 of Set 6 | port moresby
# Processing Record 6 of Set 6 | nanortalik
# Processing Record 7 of Set 6 | margate
# Processing Record 8 of Set 6 | katsuura
# Processing Record 9 of Set 6 | trat
# Processing Record 10 of Set 6 | armacao dos buzios
# armacao dos buzios not found. Skipping...
# Processing Record 11 of Set 6 | mnogovershinnyy
# Processing Record 12 of Set 6 | forestville
# Processing Record 13 of Set 6 | paamiut
# Processing Record 14 of Set 6 | khandyga
# Processing Record 15 of Set 6 | toora-khem
# Processing Record 16 of Set 6 | bathsheba
# Processing Record 17 of Set 6 | palu
# Processing Record 18 of Set 6 | ligayan
# Processing Record 19 of Set 6 | khonsa
# Processing Record 20 of Set 6 | san quintin
# Processing Record 21 of Set 6 | neryungri
# Processing Record 22 of Set 6 | naples
# Processing Record 23 of Set 6 | tsihombe
# tsihombe not found. Skipping...
# Processing Record 24 of Set 6 | buchanan
# Processing Record 25 of Set 6 | bubaque
# Processing Record 26 of Set 6 | narsaq
# Processing Record 27 of Set 6 | chaiya
# Processing Record 28 of Set 6 | saint-francois
# Processing Record 29 of Set 6 | chokurdakh
# Processing Record 30 of Set 6 | kuching
# Processing Record 31 of Set 6 | gulbarga
# Processing Record 32 of Set 6 | lorengau
# Processing Record 33 of Set 6 | padang
# Processing Record 34 of Set 6 | the pas
# Processing Record 35 of Set 6 | vaitupu
# vaitupu not found. Skipping...
# Processing Record 36 of Set 6 | sioux lookout
# Processing Record 37 of Set 6 | kirakira
# Processing Record 38 of Set 6 | sola
# Processing Record 39 of Set 6 | ulaangom
# Processing Record 40 of Set 6 | bilgoraj
# Processing Record 41 of Set 6 | batesville
# Processing Record 42 of Set 6 | bridgend
# Processing Record 43 of Set 6 | acurenam
# Processing Record 44 of Set 6 | porto seguro
# Processing Record 45 of Set 6 | standish
# Processing Record 46 of Set 6 | cossato
# Processing Record 47 of Set 6 | champerico
# Processing Record 48 of Set 6 | gedzhukh
# Processing Record 49 of Set 6 | palabuhanratu
# palabuhanratu not found. Skipping...
# Processing Record 50 of Set 6 | roros
# Processing Record 51 of Set 6 | salalah
# Processing Record 52 of Set 6 | torbay
# Processing Record 53 of Set 6 | soure
# Processing Record 54 of Set 6 | kochki
# Processing Record 55 of Set 6 | young
# Processing Record 56 of Set 6 | rocha
# Processing Record 57 of Set 6 | flin flon
# Processing Record 58 of Set 6 | opuwo
# Processing Record 59 of Set 6 | san juan bautista
# Processing Record 60 of Set 6 | waipawa
# Waiting 44 seconds for next API time slot...
# Processing Record 1 of Set 7 | salinas
# Processing Record 2 of Set 7 | seoul
# Processing Record 3 of Set 7 | sulangan
# Processing Record 4 of Set 7 | passo de camaragibe
# Processing Record 5 of Set 7 | ahuimanu
# Processing Record 6 of Set 7 | cockburn town
# Processing Record 7 of Set 7 | gilgit
# Processing Record 8 of Set 7 | sorland
# Processing Record 9 of Set 7 | sitka
# Processing Record 10 of Set 7 | satitoa
# satitoa not found. Skipping...
# Processing Record 11 of Set 7 | khatanga
# Processing Record 12 of Set 7 | santa cruz
# Processing Record 13 of Set 7 | cayenne
# Processing Record 14 of Set 7 | flinders
# Processing Record 15 of Set 7 | neosho
# Processing Record 16 of Set 7 | haren
# Processing Record 17 of Set 7 | inhambane
# Processing Record 18 of Set 7 | karratha
# Processing Record 19 of Set 7 | pangnirtung
# Processing Record 20 of Set 7 | sapanta
# Processing Record 21 of Set 7 | celestun
# Processing Record 22 of Set 7 | ternate
# Processing Record 23 of Set 7 | fort nelson
# Processing Record 24 of Set 7 | roald
# Processing Record 25 of Set 7 | parthenay
# Processing Record 26 of Set 7 | derventa
# Processing Record 27 of Set 7 | reconquista
# Processing Record 28 of Set 7 | banjar
# Processing Record 29 of Set 7 | yeppoon
# Processing Record 30 of Set 7 | umm lajj
# Processing Record 31 of Set 7 | tangshan
# Processing Record 32 of Set 7 | victor harbor
# Processing Record 33 of Set 7 | mahon
# Processing Record 34 of Set 7 | lucapa
# Processing Record 35 of Set 7 | burica
# burica not found. Skipping...
# Processing Record 36 of Set 7 | poum
# Processing Record 37 of Set 7 | bianzhuang
# Processing Record 38 of Set 7 | taitung
# Processing Record 39 of Set 7 | minjur
# Processing Record 40 of Set 7 | samarai
# Processing Record 41 of Set 7 | corato
# Processing Record 42 of Set 7 | belen
# Processing Record 43 of Set 7 | mago
# Processing Record 44 of Set 7 | henties bay
# Processing Record 45 of Set 7 | elizabeth city
# Processing Record 46 of Set 7 | costinesti
# Processing Record 47 of Set 7 | bada
# Processing Record 48 of Set 7 | stornoway
# Processing Record 49 of Set 7 | pandan
# Processing Record 50 of Set 7 | broome
# Processing Record 51 of Set 7 | saint george
# Processing Record 52 of Set 7 | ossora
# Processing Record 53 of Set 7 | surt
# Processing Record 54 of Set 7 | keti bandar
# Processing Record 55 of Set 7 | burgos
# Processing Record 56 of Set 7 | doctor arroyo
# Processing Record 57 of Set 7 | tautira
# Processing Record 58 of Set 7 | moose factory
# Processing Record 59 of Set 7 | kotdwara
# Processing Record 60 of Set 7 | tessalit
# Waiting 42 seconds for next API time slot...
# Processing Record 1 of Set 8 | pochutla
# Processing Record 2 of Set 8 | samusu
# samusu not found. Skipping...
# Processing Record 3 of Set 8 | veracruz
# Processing Record 4 of Set 8 | itarema
# Processing Record 5 of Set 8 | ardino
# Processing Record 6 of Set 8 | una
# Processing Record 7 of Set 8 | tigre
# Processing Record 8 of Set 8 | zeya
# Processing Record 9 of Set 8 | rundu
# Processing Record 10 of Set 8 | acari
# Processing Record 11 of Set 8 | yangambi
# Processing Record 12 of Set 8 | smirnykh
# Processing Record 13 of Set 8 | semey
# Processing Record 14 of Set 8 | mergui
# mergui not found. Skipping...
# Processing Record 15 of Set 8 | xuddur
# Processing Record 16 of Set 8 | duluth
# Processing Record 17 of Set 8 | scottsbluff
# Processing Record 18 of Set 8 | irtyshskiy
# Processing Record 19 of Set 8 | baykalovo
# Processing Record 20 of Set 8 | kaputa
# Processing Record 21 of Set 8 | bela vista
# Processing Record 22 of Set 8 | yining
# Processing Record 23 of Set 8 | sapernoye
# Processing Record 24 of Set 8 | pingzhuang
# Processing Record 25 of Set 8 | pati
# Processing Record 26 of Set 8 | sao filipe
# Processing Record 27 of Set 8 | banda aceh
# Processing Record 28 of Set 8 | vermilion
# Processing Record 29 of Set 8 | tazovskiy
# Processing Record 30 of Set 8 | murray bridge
# Processing Record 31 of Set 8 | methoni
# Processing Record 32 of Set 8 | los llanos de aridane
# Processing Record 33 of Set 8 | gat
# Processing Record 34 of Set 8 | shizilu
# Processing Record 35 of Set 8 | shelburne
# Processing Record 36 of Set 8 | papara
# Processing Record 37 of Set 8 | beloha
# Processing Record 38 of Set 8 | necochea
# Processing Record 39 of Set 8 | rio grande
# Processing Record 40 of Set 8 | hun
# Processing Record 41 of Set 8 | naryan-mar
# Processing Record 42 of Set 8 | trincomalee
# Processing Record 43 of Set 8 | tonekabon
# Processing Record 44 of Set 8 | sabha
# Processing Record 45 of Set 8 | malwan
# malwan not found. Skipping...
# Processing Record 46 of Set 8 | havoysund
# Processing Record 47 of Set 8 | northam
# Processing Record 48 of Set 8 | bilibino
# Processing Record 49 of Set 8 | cay
# Processing Record 50 of Set 8 | lasa
# Processing Record 51 of Set 8 | talaya
# Processing Record 52 of Set 8 | ngong
# Processing Record 53 of Set 8 | mudu
# Processing Record 54 of Set 8 | vanimo
# Processing Record 55 of Set 8 | acarau
# Processing Record 56 of Set 8 | woodward
# Processing Record 57 of Set 8 | namatanai
# Processing Record 58 of Set 8 | lazaro cardenas
# Processing Record 59 of Set 8 | san pedro
# Processing Record 60 of Set 8 | shimoda
# Waiting 42 seconds for next API time slot...
# Processing Record 1 of Set 9 | barcelos
# Processing Record 2 of Set 9 | goderich
# Processing Record 3 of Set 9 | sal rei
# Processing Record 4 of Set 9 | gannan
# Processing Record 5 of Set 9 | komatsushima
# Processing Record 6 of Set 9 | santa lucia
# Processing Record 7 of Set 9 | dunedin
# Processing Record 8 of Set 9 | udachnyy
# Processing Record 9 of Set 9 | gumdag
# Processing Record 10 of Set 9 | mtimbira
# Processing Record 11 of Set 9 | eyl
# Processing Record 12 of Set 9 | oranjemund
# Processing Record 13 of Set 9 | nisia floresta
# Processing Record 14 of Set 9 | saint-pierre
# Processing Record 15 of Set 9 | kontagora
# Processing Record 16 of Set 9 | te anau
# Processing Record 17 of Set 9 | taiyuan
# Processing Record 18 of Set 9 | wageningen
# Processing Record 19 of Set 9 | yulin
# Processing Record 20 of Set 9 | tari
# Processing Record 21 of Set 9 | tomatlan
# Processing Record 22 of Set 9 | pulaski
# Processing Record 23 of Set 9 | zanjan
# Processing Record 24 of Set 9 | severodvinsk
# Processing Record 25 of Set 9 | sobolevo
# Processing Record 26 of Set 9 | bamiantong
# Processing Record 27 of Set 9 | grindavik
# Processing Record 28 of Set 9 | quatre cocos
# Processing Record 29 of Set 9 | am timan
# Processing Record 30 of Set 9 | topeka
# Processing Record 31 of Set 9 | mahibadhoo
# Processing Record 32 of Set 9 | fukue
# Processing Record 33 of Set 9 | saint anthony
# Processing Record 34 of Set 9 | moerai
# Processing Record 35 of Set 9 | russkiy aktash
# Processing Record 36 of Set 9 | stephenville
# Processing Record 37 of Set 9 | presidencia roque saenz pena
# Processing Record 38 of Set 9 | goulburn
# Processing Record 39 of Set 9 | ahipara
# Processing Record 40 of Set 9 | christchurch
# Processing Record 41 of Set 9 | richards bay
# Processing Record 42 of Set 9 | clovis
# Processing Record 43 of Set 9 | biabou
# Processing Record 44 of Set 9 | tortosa
# Processing Record 45 of Set 9 | turayf
# Processing Record 46 of Set 9 | nieuw amsterdam
# Processing Record 47 of Set 9 | toktogul
# Processing Record 48 of Set 9 | srednekolymsk
# Processing Record 49 of Set 9 | lexington
# Processing Record 50 of Set 9 | oktyabrskoye
# Processing Record 51 of Set 9 | brae
# Processing Record 52 of Set 9 | santa fe
# Processing Record 53 of Set 9 | evensk
# Processing Record 54 of Set 9 | ust-kulom
# Processing Record 55 of Set 9 | tawang
# Processing Record 56 of Set 9 | bloomsburg
# Processing Record 57 of Set 9 | benguela
# Processing Record 58 of Set 9 | portobelo
# Processing Record 59 of Set 9 | karkaralinsk
# karkaralinsk not found. Skipping...
# Processing Record 60 of Set 9 | mikkeli
# Waiting 42 seconds for next API time slot...
# Processing Record 1 of Set 10 | waingapu
# Processing Record 2 of Set 10 | sorvag
# sorvag not found. Skipping...
# Processing Record 3 of Set 10 | el jicaro
# Processing Record 4 of Set 10 | hofn
# Processing Record 5 of Set 10 | husavik
# Processing Record 6 of Set 10 | tura
# Processing Record 7 of Set 10 | emba
# Processing Record 8 of Set 10 | doha
# Processing Record 9 of Set 10 | jurm
# Processing Record 10 of Set 10 | kundiawa
# Processing Record 11 of Set 10 | sovetskiy
# Processing Record 12 of Set 10 | maturin
# Processing Record 13 of Set 10 | mogadishu
# Processing Record 14 of Set 10 | minab
# Processing Record 15 of Set 10 | sokna
# Processing Record 16 of Set 10 | haverfordwest
# Processing Record 17 of Set 10 | storforshei
# Processing Record 18 of Set 10 | kastamonu
# Processing Record 19 of Set 10 | fussa
# Processing Record 20 of Set 10 | kiama
# Processing Record 21 of Set 10 | calbuco
# Processing Record 22 of Set 10 | catamarca
# Processing Record 23 of Set 10 | dawson creek
# Processing Record 24 of Set 10 | biltine
# Processing Record 25 of Set 10 | fairbanks
# Processing Record 26 of Set 10 | yambio
# Processing Record 27 of Set 10 | dawlatabad
# Processing Record 28 of Set 10 | aljezur
# Processing Record 29 of Set 10 | iquitos
# Processing Record 30 of Set 10 | westport
# Processing Record 31 of Set 10 | tabiauea
# tabiauea not found. Skipping...
# Processing Record 32 of Set 10 | tigil
# Processing Record 33 of Set 10 | umzimvubu
# umzimvubu not found. Skipping...
# Processing Record 34 of Set 10 | urumqi
# Processing Record 35 of Set 10 | hede
# Processing Record 36 of Set 10 | beisfjord
# Processing Record 37 of Set 10 | saint-joseph
# Processing Record 38 of Set 10 | hamilton
# Processing Record 39 of Set 10 | praia
# Processing Record 40 of Set 10 | lobito
# Processing Record 41 of Set 10 | abu dhabi
# Processing Record 42 of Set 10 | havre-saint-pierre
# Processing Record 43 of Set 10 | harnosand
# Processing Record 44 of Set 10 | arboledas
# Processing Record 45 of Set 10 | azimur
# azimur not found. Skipping...
# Processing Record 46 of Set 10 | kovrov
# Processing Record 47 of Set 10 | antsla
# Processing Record 48 of Set 10 | moose jaw
# Processing Record 49 of Set 10 | tezu
# Processing Record 50 of Set 10 | binzhou
# Processing Record 51 of Set 10 | byron bay
# Processing Record 52 of Set 10 | dali
# Processing Record 53 of Set 10 | tabou
# Processing Record 54 of Set 10 | muscat
# Processing Record 55 of Set 10 | horadiz
# Processing Record 56 of Set 10 | porciuncula
# Processing Record 57 of Set 10 | sinnamary
# Processing Record 58 of Set 10 | bay roberts
# Processing Record 59 of Set 10 | formoso do araguaia
# formoso do araguaia not found. Skipping...
# Processing Record 60 of Set 10 | lushunkou
# lushunkou not found. Skipping...
# Waiting 43 seconds for next API time slot...
# Processing Record 1 of Set 11 | dongli
# Processing Record 2 of Set 11 | waitati
# Processing Record 3 of Set 11 | palmeiras de goias
# Processing Record 4 of Set 11 | puerto escondido
# Processing Record 5 of Set 11 | jabinyanah
# Processing Record 6 of Set 11 | kavaratti
# Processing Record 7 of Set 11 | kansanshi
# Processing Record 8 of Set 11 | sumbawa
# sumbawa not found. Skipping...
# Processing Record 9 of Set 11 | tepoztlan
# Processing Record 10 of Set 11 | bokspits
# bokspits not found. Skipping...
# Processing Record 11 of Set 11 | hobyo
# Processing Record 12 of Set 11 | coahuayana
# Processing Record 13 of Set 11 | gold coast
# Processing Record 14 of Set 11 | nakhon phanom
# Processing Record 15 of Set 11 | karasuk
# Processing Record 16 of Set 11 | megion
# Processing Record 17 of Set 11 | geresk
# geresk not found. Skipping...
# Processing Record 18 of Set 11 | santo angelo
# Processing Record 19 of Set 11 | oxford
# Processing Record 20 of Set 11 | ha tinh
# Processing Record 21 of Set 11 | manggar
# Processing Record 22 of Set 11 | ji-parana
# ji-parana not found. Skipping...
# Processing Record 23 of Set 11 | raseiniai
# Processing Record 24 of Set 11 | hay river
# Processing Record 25 of Set 11 | bonthe
# Processing Record 26 of Set 11 | campos
# Processing Record 27 of Set 11 | cazones
# Processing Record 28 of Set 11 | nelson bay
# Processing Record 29 of Set 11 | annandale
# Processing Record 30 of Set 11 | andros town
# Processing Record 31 of Set 11 | bandundu
# Processing Record 32 of Set 11 | naze
# Processing Record 33 of Set 11 | the valley
# Processing Record 34 of Set 11 | neuquen
# Processing Record 35 of Set 11 | roma
# Processing Record 36 of Set 11 | benicarlo
# Processing Record 37 of Set 11 | awbari
# Processing Record 38 of Set 11 | beya
# Processing Record 39 of Set 11 | mogadouro
# Processing Record 40 of Set 11 | tasbuget
# tasbuget not found. Skipping...
# Processing Record 41 of Set 11 | virginia beach
# Processing Record 42 of Set 11 | pangai
# Processing Record 43 of Set 11 | puerto gaitan
# Processing Record 44 of Set 11 | deep river
# Processing Record 45 of Set 11 | wembley
# Processing Record 46 of Set 11 | tema
# Processing Record 47 of Set 11 | guantanamo
# Processing Record 48 of Set 11 | ozinki
# Processing Record 49 of Set 11 | bundaberg
# Processing Record 50 of Set 11 | berlevag
# Processing Record 51 of Set 11 | kamenskoye
# kamenskoye not found. Skipping...
# Processing Record 52 of Set 11 | rudbar
# Processing Record 53 of Set 11 | martapura
# Processing Record 54 of Set 11 | hami
# Processing Record 55 of Set 11 | bealanana
# Processing Record 56 of Set 11 | springbok
# Processing Record 57 of Set 11 | korla
# Processing Record 58 of Set 11 | yunjinghong
# yunjinghong not found. Skipping...
# Processing Record 59 of Set 11 | halalo
# halalo not found. Skipping...
# Processing Record 60 of Set 11 | zastron
# Waiting 44 seconds for next API time slot...
# Processing Record 1 of Set 12 | auki
# Processing Record 2 of Set 12 | luan
# Processing Record 3 of Set 12 | slantsy
# Processing Record 4 of Set 12 | wanning
# Processing Record 5 of Set 12 | itubera
# Processing Record 6 of Set 12 | sinop
# Processing Record 7 of Set 12 | la palma
# Processing Record 8 of Set 12 | colombia
# Processing Record 9 of Set 12 | muros
# Processing Record 10 of Set 12 | gravdal
# Processing Record 11 of Set 12 | chagda
# chagda not found. Skipping...
# Processing Record 12 of Set 12 | krasnomayskiy
# Processing Record 13 of Set 12 | tual
# Processing Record 14 of Set 12 | cabedelo
# Processing Record 15 of Set 12 | santiago del estero
# Processing Record 16 of Set 12 | kempsey
# Processing Record 17 of Set 12 | bitung
# Processing Record 18 of Set 12 | san luis
# Processing Record 19 of Set 12 | puro
# Processing Record 20 of Set 12 | rawson
# Processing Record 21 of Set 12 | erenhot
# Processing Record 22 of Set 12 | hihifo
# hihifo not found. Skipping...
# Processing Record 23 of Set 12 | dianopolis
# dianopolis not found. Skipping...
# Processing Record 24 of Set 12 | tete
# Processing Record 25 of Set 12 | spornoye
# Processing Record 26 of Set 12 | mana
# Processing Record 27 of Set 12 | conceicao da barra
# Processing Record 28 of Set 12 | kano
# Processing Record 29 of Set 12 | sabang
# Processing Record 30 of Set 12 | kuche
# kuche not found. Skipping...
# Processing Record 31 of Set 12 | okhotsk
# Processing Record 32 of Set 12 | marcona
# marcona not found. Skipping...
# Processing Record 33 of Set 12 | north platte
# Processing Record 34 of Set 12 | prainha
# Processing Record 35 of Set 12 | chany
# Processing Record 36 of Set 12 | geraldton
# Processing Record 37 of Set 12 | walvis bay
# Processing Record 38 of Set 12 | dolzhanskaya
# Processing Record 39 of Set 12 | nargana
# Processing Record 40 of Set 12 | natal
# Processing Record 41 of Set 12 | asfi
# Processing Record 42 of Set 12 | foix
# Processing Record 43 of Set 12 | warqla
# warqla not found. Skipping...
# Processing Record 44 of Set 12 | mangochi
# Processing Record 45 of Set 12 | huarmey
# Processing Record 46 of Set 12 | terme
# Processing Record 47 of Set 12 | kasongo-lunda
# Processing Record 48 of Set 12 | atar
# Processing Record 49 of Set 12 | lolua
# lolua not found. Skipping...
# Processing Record 50 of Set 12 | poienile de sub munte
# Processing Record 51 of Set 12 | half moon bay
# Processing Record 52 of Set 12 | nouakchott
# Processing Record 53 of Set 12 | muisne
# Processing Record 54 of Set 12 | skjervoy
# Processing Record 55 of Set 12 | kyshtovka
# Processing Record 56 of Set 12 | bulgan
# Processing Record 57 of Set 12 | salinopolis
# Processing Record 58 of Set 12 | vaitape
# Processing Record 59 of Set 12 | nguiu
# nguiu not found. Skipping...
# Processing Record 60 of Set 12 | uyuni
# Waiting 44 seconds for next API time slot...
# Processing Record 1 of Set 13 | dergaon
# Processing Record 2 of Set 13 | ostroh
# Processing Record 3 of Set 13 | anklam
# Processing Record 4 of Set 13 | voskresenskoye
# Processing Record 5 of Set 13 | ciras
# ciras not found. Skipping...
# Processing Record 6 of Set 13 | monrovia
# Processing Record 7 of Set 13 | kamaishi
# Processing Record 8 of Set 13 | nalut
# Processing Record 9 of Set 13 | najran
# Processing Record 10 of Set 13 | zhigansk
# Processing Record 11 of Set 13 | lianzhou
# Processing Record 12 of Set 13 | mangla
# Processing Record 13 of Set 13 | ust-nera
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Save the city data to a CSV
city_data_df = pd.DataFrame(city_data)
city_data_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 
                          'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']
city_data_df = city_data_df[city_data_column_order]
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
city_data_df
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Upernavik      GL  72.7868  -56.1549     25.41        64           0
# 1    Norman Wells      CA  65.2820 -126.8329     33.84        80          75
# 2      Sosnogorsk      RU  63.6023   53.8817     39.81        77         100
# 3       Cape Town      ZA -33.9258   18.4232     62.28        74           0
# 4       Busselton      AU -33.6500  115.3333     57.04        90          76
# ..            ...     ...      ...       ...       ...       ...         ...
# 670        Najran      SA  17.4924   44.1277     83.05        19          10
# 671      Zhigansk      RU  66.7697  123.3711     30.79        93          15
# 672      Lianzhou      CN  24.7811  112.3825     77.61        80          45
# 673        Mangla      PK  31.8931   72.3817     88.83        39           0
# 674      Ust-Nera      RU  64.5667  143.2000     30.29        88          80
#
#      Wind Speed Current Description
# 0          2.55           clear sky
# 1         12.66       broken clouds
# 2          9.46     overcast clouds
# 3          3.00           clear sky
# 4         14.36       broken clouds
# ..          ...                 ...
# 670        5.50           clear sky
# 671       16.22          few clouds
# 672        0.96    scattered clouds
# 673        6.82           clear sky
# 674        4.88       broken clouds
#
# [675 rows x 9 columns]
