# %%
# Import dependencies
import pandas as pd
import gmaps
import requests

from config import g_key

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID         City Country                 Date      Lat       Lng  \
# 0        0    Hithadhoo      MV  2021-09-26 19:43:19  -0.6000   73.0833
# 1        1  Tuktoyaktuk      CA  2021-09-26 19:43:19  69.4541 -133.0374
# 2        2       Atuona      PF  2021-09-26 19:43:19  -9.8000 -139.0333
# 3        3       Tahoua      NE  2021-09-26 19:43:20  14.8888    5.2692
# 4        4         Chuy      UY  2021-09-26 19:43:20 -33.6971  -53.4616
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     82.81        72         100       17.13
# 1     33.80        93          90       16.11
# 2     78.22        70           5       18.21
# 3     92.97        16           5        7.02
# 4     65.66        74           1        6.60

# %%
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Country        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %%
# Configure the gmaps API key
gmaps.configure(api_key=g_key)

# %%
#  6.5.2 Create a heatmap of temperatures
# Get the locations as lat/long coordinates
locations = city_data_df[['Lat', 'Lng']]
# Get the maximum temperature.  If it's less than zero, set to zero
max_temp = city_data_df["Max Temp"]
temps = [max(temp,0) for temp in max_temp]
# Generate the figure and assigned it to a variable
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
# Generate the heatmap layer and assign it to a variable
heat_layer = gmaps.heatmap_layer(locations, weights=temps,
                                 dissipating=False, max_intensity=300,
                                 point_radius=4)
# Add the heatmap layer
fig.add_layer(heat_layer)
# Call the figure to plot the data
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
humidity = city_data_df["Humidity"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
wind_speed = city_data_df["Wind Speed"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=wind_speed, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maximum temperature you would like for your trip? 90

# %%
preferred_cities_df = city_data_df.loc[(city_data_df['Max Temp'] >= 75) & 
                                       (city_data_df['Max Temp'] <= 90)]
preferred_cities_df
# Out:
#     City_ID            City Country                 Date      Lat       Lng  \
# 0         0       Hithadhoo      MV  2021-09-26 19:43:19  -0.6000   73.0833
# 2         2          Atuona      PF  2021-09-26 19:43:19  -9.8000 -139.0333
# 17       17    Puerto Ayora      EC  2021-09-26 19:43:25  -0.7393  -90.3518
# 20       20  Guerrero Negro      MX  2021-09-26 19:43:26  27.9769 -114.0611
# 26       26            Hilo      US  2021-09-26 19:33:04  19.7297 -155.0900
# 34       34          Kupang      ID  2021-09-26 19:43:30 -10.1667  123.5833
# 37       37      Georgetown      MY  2021-09-26 19:38:36   5.4112  100.3354
# 43       43            Mayo      US  2021-09-26 19:43:33  38.8876  -76.5119
# 45       45       Kalianget      ID  2021-09-26 19:43:34  -7.0500  113.9333
# 50       50          Laguna      US  2021-09-26 19:43:35  38.4210 -121.4238
#
#     Max Temp  Humidity  Cloudiness  Wind Speed
# 0      82.81        72         100       17.13
# 2      78.22        70           5       18.21
# 17     78.76        83          79        9.84
# 20     75.65        59           7       15.48
# 26     79.79        91          90        6.91
# 34     75.18        84          48        6.24
# 37     76.95        98          20        5.99
# 43     77.07        41           1        8.99
# 45     80.11        74          12        9.78
# 50     88.21        51           1        8.05

# %%
preferred_cities_df.count()
# Out:
# City_ID       10
# City          10
# Country       10
# Date          10
# Lat           10
# Lng           10
# Max Temp      10
# Humidity      10
# Cloudiness    10
# Wind Speed    10
# dtype: int64

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#               City Country  Max Temp      Lat       Lng Hotel Name
# 0        Hithadhoo      MV     82.81  -0.6000   73.0833
# 2           Atuona      PF     78.22  -9.8000 -139.0333
# 17    Puerto Ayora      EC     78.76  -0.7393  -90.3518
# 20  Guerrero Negro      MX     75.65  27.9769 -114.0611
# 26            Hilo      US     79.79  19.7297 -155.0900
# 34          Kupang      ID     75.18 -10.1667  123.5833
# 37      Georgetown      MY     76.95   5.4112  100.3354
# 43            Mayo      US     77.07  38.8876  -76.5119
# 45       Kalianget      ID     80.11  -7.0500  113.9333
# 50          Laguna      US     88.21  38.4210 -121.4238

# %%
# Set parameters to search for a hotel.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
    # Grab the first hotel from the results and store the name.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")

hotels
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 38.4240827, 'lng': -121.3987067},
#     'viewport': {'northeast': {'lat': 38.4255044802915,
#       'lng': -121.3974215197085},
#      'southwest': {'lat': 38.4228065197085, 'lng': -121.4001194802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Holiday Inn Express & Suites Elk Grove Central - Hwy 99, an IHG Hotel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2252,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105871328003516338772">Holiday Inn Express &amp; Suites Elk Grove Central - Hwy 99, an IHG Hotel</a>'],
#      'photo_reference': 'Aap_uEAScBM8rG8PLVipx4rG3t84GkNK00L1JD7QSmJQrzuJzKJU9Heey5lDVbnSl7-sMfbJTZ91c49kWWkoI5u8Aryz1AlwSM83C-e_4O_oebg4vNTG6d8_X1uaICdBwxE0Z6Hv0dB_-ZB8f8D9t0V90nocYVl0ZSq0uy_e11rHtpfdO7I5',
#      'width': 4000}],
#    'place_id': 'ChIJz2OBV1XGmoAR8QvqDT_bBN8',
#    'plus_code': {'compound_code': 'CJF2+JG Elk Grove, CA, USA',
#     'global_code': '84CWCJF2+JG'},
#    'rating': 4.3,
#    'reference': 'ChIJz2OBV1XGmoAR8QvqDT_bBN8',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 578,
#    'vicinity': '9175 West Stockton Boulevard, Elk Grove'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 38.42277000000001, 'lng': -121.3976085},
#     'viewport': {'northeast': {'lat': 38.42414803029151,
#       'lng': -121.3964820697085},
#      'southwest': {'lat': 38.42145006970851, 'lng': -121.3991800302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hilton Garden Inn Sacramento Elk Grove',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 857,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103854883706246225443">Hilton Garden Inn Sacramento Elk Grove</a>'],
#      'photo_reference': 'Aap_uEBtcLTXmCVcwGWFXdmFo75qJmkQs3Ae2EVzqCGwmMqvllmTjGvUVQ9TeSDpTrX5Nx6cibyO5JUTXSPrdc-seLp4MjwnsDP2qeNXGmZ56LY047nS-6-XJgRYAupMuybk3dOE3v_gZKT3uabLGza8XY8Q-_WvaMTzioH1L8baf0YJq3JZ',
#      'width': 1280}],
#    'place_id': 'ChIJ3d8jcwDHmoAR5jvwcQhFsLk',
#    'plus_code': {'compound_code': 'CJF2+4X Elk Grove, CA, USA',
#     'global_code': '84CWCJF2+4X'},
#    'rating': 4.3,
#    'reference': 'ChIJ3d8jcwDHmoAR5jvwcQhFsLk',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 551,
#    'vicinity': '9241 Laguna Springs Drive, Elk Grove'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 38.4552377, 'lng': -121.4081651},
#     'viewport': {'northeast': {'lat': 38.4564741802915,
#       'lng': -121.4067255197085},
#      'southwest': {'lat': 38.4537762197085, 'lng': -121.4094234802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Fairfield Inn & Suites by Marriott Sacramento Elk Grove',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1366,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112200545212920338366">Fairfield Inn &amp; Suites by Marriott Sacramento Elk Grove</a>'],
#      'photo_reference': 'Aap_uEAJgdLQ2_-mYSE0VgFZGIYD7cLyBJV_27ZOwh7p2jNmEFgjY0mKXDMEXHNnA3Pfq_gIKwbugaol-rLY4M0Xnf1m7yoM_Nvd5w1dNI5igqnujSgJynssJi0e6jYjLSI_eRGmXRCoxCPSJ5Zz5TMTWX13Px3gtv8xM6wighj-zj6l8BQt',
#      'width': 2048}],
#    'place_id': 'ChIJD3CQZXnGmoARefBabWd9NDs',
#    'plus_code': {'compound_code': 'FH4R+3P Elk Grove, CA, USA',
#     'global_code': '84CWFH4R+3P'},
#    'rating': 4.3,
#    'reference': 'ChIJD3CQZXnGmoARefBabWd9NDs',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 342,
#    'vicinity': '8058 Orchard Loop Lane, Elk Grove'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 38.4101159, 'lng': -121.4791574},
#     'viewport': {'northeast': {'lat': 38.4112804802915,
#       'lng': -121.4777600197085},
#      'southwest': {'lat': 38.4085825197085, 'lng': -121.4804579802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Holiday Inn Express & Suites Elk Grove West I-5, an IHG Hotel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1068,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104888396632548196199">Holiday Inn Express &amp; Suites Elk Grove West I-5, an IHG Hotel</a>'],
#      'photo_reference': 'Aap_uEDXLyfk32PDFkNkE2A3sLDJ4VIfPxxlAtcnJf4AUNqu4Px-A34YEUF_no-VCS58FeZHP4Z8fGmR3fmrnxYKvoU69oPrTaYAilFakkroGJHvPT20St4oc_6qjp_w4kCQbmy3ajAHQ-6RuwnfGDzWqGiUvuymSN-7ph7x3b1t7_ylE7sK',
#      'width': 1900}],
#    'place_id': 'ChIJrfmk8u_ImoARReeJBg7GUXI',
#    'plus_code': {'compound_code': 'CG6C+28 Elk Grove, CA, USA',
#     'global_code': '84CWCG6C+28'},
#    'rating': 4.1,
#    'reference': 'ChIJrfmk8u_ImoARReeJBg7GUXI',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 312,
#    'vicinity': '2460 Maritime Drive, Elk Grove'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 38.44925569999999, 'lng': -121.4084061},
#     'viewport': {'northeast': {'lat': 38.4506667802915,
#       'lng': -121.4070577197085},
#      'southwest': {'lat': 38.4479688197085, 'lng': -121.4097556802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'The Westerner, A Mutual Housing Community',
#    'opening_hours': {'open_now': False},
#    'place_id': 'ChIJbROOKnvGmoARvY12Fjd38n0',
#    'plus_code': {'compound_code': 'CHXR+PJ Elk Grove, CA, USA',
#     'global_code': '84CWCHXR+PJ'},
#    'rating': 3.9,
#    'reference': 'ChIJbROOKnvGmoARvY12Fjd38n0',
#    'scope': 'GOOGLE',
#    'types': ['rv_park', 'lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 18,
#    'vicinity': '8476 West Stockton Boulevard # 32, Elk Grove'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 38.4271649, 'lng': -121.411668},
#     'viewport': {'northeast': {'lat': 38.42845648029149,
#       'lng': -121.4104068697085},
#      'southwest': {'lat': 38.42575851970849, 'lng': -121.4131048302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': "Tracy Brown's House of Jesus",
#    'place_id': 'ChIJEe_qln3HmoARAOSiNegr1aY',
#    'plus_code': {'compound_code': 'CHGQ+V8 Elk Grove, CA, USA',
#     'global_code': '84CWCHGQ+V8'},
#    'rating': 5,
#    'reference': 'ChIJEe_qln3HmoARAOSiNegr1aY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': '7807 River Otter Way, Elk Grove'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 38.41907109999999, 'lng': -121.3922576},
#     'viewport': {'northeast': {'lat': 38.42035818029149,
#       'lng': -121.3907584197085},
#      'southwest': {'lat': 38.41766021970849, 'lng': -121.3934563802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'TownePlace Suites by Marriott Sacramento Elk Grove',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1366,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101415171552181482764">TownePlace Suites by Marriott Sacramento Elk Grove</a>'],
#      'photo_reference': 'Aap_uEBwD4-OE93Pb6YZv5jrjPDJoTTquqID0dZUKRvO9m5sSiYrGP69C5w9C8b96o8NBAJPsMVsR7ZnLNBTBZ-LAu_SOYlp_lXKh87RjLgifh0J0qWVyZkefGEzNvFzexTLAxwEqKy9P3Rc5VmJoDA38tBsOgOAs1WlXc8JCPfKwhXfgUE_',
#      'width': 2048}],
#    'place_id': 'ChIJ2_nNe-XHmoARSf3M0oMyKvY',
#    'plus_code': {'compound_code': 'CJ95+J3 Elk Grove, CA, USA',
#     'global_code': '84CWCJ95+J3'},
#    'rating': 4.8,
#    'reference': 'ChIJ2_nNe-XHmoARSf3M0oMyKvY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 4,
#    'vicinity': '9320 East Stockton Boulevard, Elk Grove'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 38.440947, 'lng': -121.404288},
#     'viewport': {'northeast': {'lat': 38.44236473029149,
#       'lng': -121.4025863697085},
#      'southwest': {'lat': 38.4396667697085, 'lng': -121.4052843302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Laguna Village RV Park',
#    'place_id': 'ChIJBbDXfPbHmoARF-xevIrjcmg',
#    'plus_code': {'compound_code': 'CHRW+97 Elk Grove, CA, USA',
#     'global_code': '84CWCHRW+97'},
#    'rating': 4.1,
#    'reference': 'ChIJBbDXfPbHmoARF-xevIrjcmg',
#    'scope': 'GOOGLE',
#    'types': ['rv_park', 'lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 11,
#    'vicinity': '8686 West Stockton Boulevard, Elk Grove'},
#   {'business_status': 'CLOSED_TEMPORARILY',
#    'geometry': {'location': {'lat': 38.4134189, 'lng': -121.4599259},
#     'viewport': {'northeast': {'lat': 38.4147574802915,
#       'lng': -121.4585827197085},
#      'southwest': {'lat': 38.4120595197085, 'lng': -121.4612806802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Mira Lago',
#    'permanently_closed': True,
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101811383362269775874">Robert Levin</a>'],
#      'photo_reference': 'Aap_uECtLNZiKDVIvlizyWtGVz0IskJNfcfE4s_k8ceKXuZ0R3p89QL1LLqVcumQ6IqFXV4m39sfBI8emC_a6t3y-eLIgkw4-zBaaI2W-EFcenm1X-2K9029wxhne354xa60FrRaZGHPsJ5xKfb-Lv5ujBXtndVJXwLIFQO7jFDYEvHrGy9R',
#      'width': 4032}],
#    'place_id': 'ChIJm8rRgAvJmoAR6ki1BmMqc_o',
#    'plus_code': {'compound_code': 'CG7R+92 Elk Grove, CA, USA',
#     'global_code': '84CWCG7R+92'},
#    'reference': 'ChIJm8rRgAvJmoAR6ki1BmMqc_o',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': '3899-3801 Lake Terrace Drive, Elk Grove'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 38.4036959, 'lng': -121.383458},
#     'viewport': {'northeast': {'lat': 38.40497758029149,
#       'lng': -121.3826112197085},
#      'southwest': {'lat': 38.4022796197085, 'lng': -121.3853091802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Oaks Mobile Home Community',
#    'photos': [{'height': 4216,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102844598608092286357">LCP360 Production</a>'],
#      'photo_reference': 'Aap_uED0hwE3-wTgo3IL6dnpHUw8rsXXCC-z9pQzNgsf4np302APUmqnapgAgNw_2UJ7LZlXjyyJGDCtK-RXAF5ThbiFysUEbEsnaOQ_LzrTStTbpCOMo85IvT8Lsx7bOtdxmHIrSRJnY0WmpnoQWX-it5AK1OTNepIPtLZedSG4P5lh99A',
#      'width': 6324}],
#    'place_id': 'ChIJmw6Hr27HmoARSYyJo_2HVkY',
#    'plus_code': {'compound_code': 'CJ38+FJ Elk Grove, CA, USA',
#     'global_code': '84CWCJ38+FJ'},
#    'rating': 4,
#    'reference': 'ChIJmw6Hr27HmoARSYyJo_2HVkY',
#    'scope': 'GOOGLE',
#    'types': ['rv_park', 'lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 39,
#    'vicinity': '9761 East Stockton Boulevard, Elk Grove'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 38.4593917, 'lng': -121.429395},
#     'viewport': {'northeast': {'lat': 38.4606653302915,
#       'lng': -121.4279238197085},
#      'southwest': {'lat': 38.45796736970851, 'lng': -121.4306217802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Bridgeport Apartments',
#    'photos': [{'height': 509,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110752816395051137672">Forrest Battles</a>'],
#      'photo_reference': 'Aap_uEAPnoM5hAcl9cnynDt3dTn659-4LttA6a0-LpP0uglJiEa_-3hmzzO5_J8iJ7u3QvsJwGbtCkdqnvnYaKIJKvdPSUYlGPoCK2polx8dsqOZOB88P8Kj0hCQwNQK_rrk7L1_nrPPoIyDZvLpsc4wsjapEcw7rNCay4g43dibphJrl3an',
#      'width': 1207}],
#    'place_id': 'ChIJ_Yg1kkvFmoARsYwEGu73ffM',
#    'plus_code': {'compound_code': 'FH5C+Q6 Sacramento, CA, USA',
#     'global_code': '84CWFH5C+Q6'},
#    'reference': 'ChIJ_Yg1kkvFmoARsYwEGu73ffM',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'Sacramento'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 38.4596426, 'lng': -121.4208145},
#     'viewport': {'northeast': {'lat': 38.46099563029149,
#       'lng': -121.4195789197085},
#      'southwest': {'lat': 38.45829766970849, 'lng': -121.4222768802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Amadu’s Room and board',
#    'place_id': 'ChIJazTNeUvFmoARUviHnZrga1g',
#    'plus_code': {'compound_code': 'FH5H+VM Sacramento, CA, USA',
#     'global_code': '84CWFH5H+VM'},
#    'reference': 'ChIJazTNeUvFmoARUviHnZrga1g',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': '7161 Surreywood Way, Sacramento'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 38.3815383, 'lng': -121.4163742},
#     'viewport': {'northeast': {'lat': 38.3828846802915,
#       'lng': -121.4149054697085},
#      'southwest': {'lat': 38.3801867197085, 'lng': -121.4176034302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'The Mesa at Laguna Ridge',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110735496233443789153">Mowe Hy</a>'],
#      'photo_reference': 'Aap_uEAIrdRC3mJevcgrZKD3kYvNy_SBoM8exydYqeN5HpeYJcMNR4Vh9ApN-x94siShAWR_fv4-RdVPxScL8Tiu23m3QNN4Mc-_slE3Dzf5Bbci90K1p1kIHqdTJt8Jnta46K9-WPr9fXOTHJMfLxi5Uqu50mpdNYirx5PHoah-NIIi7My9',
#      'width': 3024}],
#    'place_id': 'ChIJ1XGBS0HHmoARMAJKmaQPTTI',
#    'plus_code': {'compound_code': '9HJM+JF Elk Grove, CA, USA',
#     'global_code': '84CW9HJM+JF'},
#    'rating': 4.2,
#    'reference': 'ChIJ1XGBS0HHmoARMAJKmaQPTTI',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 6,
#    'vicinity': '10371 Bruceville Road, Elk Grove'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 38.4087993, 'lng': -121.3716178},
#     'viewport': {'northeast': {'lat': 38.4101496302915,
#       'lng': -121.3703003697085},
#      'southwest': {'lat': 38.4074516697085, 'lng': -121.3729983302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Extended stay hotel',
#    'place_id': 'ChIJZxX__mjHmoARY1bLSXEFarg',
#    'plus_code': {'compound_code': 'CJ5H+G9 Elk Grove, CA, USA',
#     'global_code': '84CWCJ5H+G9'},
#    'reference': 'ChIJZxX__mjHmoARY1bLSXEFarg',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'Elk Grove'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 38.4087993, 'lng': -121.3716178},
#     'viewport': {'northeast': {'lat': 38.4101496302915,
#       'lng': -121.3703003697085},
#      'southwest': {'lat': 38.4074516697085, 'lng': -121.3729983302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': "Larry Lee's Cave",
#    'place_id': 'ChIJa8xYwAjHmoARkfhgMdfzjvQ',
#    'plus_code': {'compound_code': 'CJ5H+G9 Elk Grove, CA, USA',
#     'global_code': '84CWCJ5H+G9'},
#    'reference': 'ChIJa8xYwAjHmoARkfhgMdfzjvQ',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'Elk Grove'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 38.46260299999999, 'lng': -121.4370917},
#     'viewport': {'northeast': {'lat': 38.4639796302915,
#       'lng': -121.4358698697085},
#      'southwest': {'lat': 38.4612816697085, 'lng': -121.4385678302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Phượng Trần',
#    'place_id': 'ChIJG7Wtx6XFmoARqZvdnwYYi34',
#    'plus_code': {'compound_code': 'FH77+25 Sacramento, CA, USA',
#     'global_code': '84CWFH77+25'},
#    'reference': 'ChIJG7Wtx6XFmoARqZvdnwYYi34',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': '8131 San Remo Way, Sacramento'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 38.3766717, 'lng': -121.4140686},
#     'viewport': {'northeast': {'lat': 38.37797483029149,
#       'lng': -121.4127203697085},
#      'southwest': {'lat': 38.37527686970849, 'lng': -121.4154183302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'TAYLOR MORRISON Sales office',
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112005724471703317146">Cornel Ecuacion</a>'],
#      'photo_reference': 'Aap_uEBHYIZ6J4hURUIc2SkUEW6-sZfcguciMUgoIn1YbtdDywi867Dn7gZ1AWmdcBAvu6HLZftUl0YsjH9aUmd3H7AzhSdSDzWD0EPDd1aUo-LPj2QW3SgvJ-UJHkPNpJm3ZK8QadwNqCFXqJANRi_CC6hbffJHXKsVuSOu14-ZXIbK0laJ',
#      'width': 4032}],
#    'place_id': 'ChIJ-dNDy5a5moAR9aMpmPySuMU',
#    'plus_code': {'compound_code': '9HGP+M9 Elk Grove, CA, USA',
#     'global_code': '84CW9HGP+M9'},
#    'rating': 5,
#    'reference': 'ChIJ-dNDy5a5moAR9aMpmPySuMU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': 'Elk Grove'}],
#  'status': 'OK'}

# %%
len(hotels['results'])
# Out:
# 17

# %%
# Add a heatmap of temperature for the vacation spots.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp, dissipating=False,
             max_intensity=300, point_radius=4)
# https://jupyter-gmaps.readthedocs.io/en/latest/tutorial.html#markers-and-symbols
# Add info boxes
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""
# Add the hotel info description box to each hotel.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)

fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
